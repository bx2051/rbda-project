# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql.functions import col, monotonically_increasing_id
from pyspark.sql import SparkSession

# Initialize a Spark session

spark = SparkSession.builder.appName("SparkStandaloneTest").getOrCreate()

spark = SparkSession.builder \
    .appName("GCSFilesRead") \
    .config("spark.executor.cores", "120") \
    .config("spark.num.executors", "6") \
    .getOrCreate() 

# file path 
file_location = "/home/bx2051/dataset1.csv"

def read_csv_with_inferred_schema(file_path):
    """
    Reads a CSV file with inferred schema.
    transfer string data type to factor

    Args:
        file_path (str): The path to the CSV file.

    Returns:
        pyspark.sql.DataFrame: The DataFrame with inferred schema.
    """
    # Read the CSV file with inferred schema
    data = spark.read \
        .option("header", "true") \
        .option("inferSchema", "true") \
        .csv(file_path)
    
    
    return data


df = read_csv_with_inferred_schema(file_location)

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql.functions import col
from pyspark.sql import SparkSession

# Initialize Spark session
spark = SparkSession.builder.appName("Feature Selection with Random Forest").getOrCreate()

# Function to train Random Forest model
def train_random_forest_model(data, feature_cols, label_col='glucose'):
    assembler = VectorAssembler(inputCols=feature_cols, outputCol="features")
    data_transformed = assembler.transform(data)
    
    # Split data into training and test sets
    train_data, test_data = data_transformed.randomSplit([0.66, 0.34], seed=1)
    
    rf = RandomForestRegressor(featuresCol="features", labelCol=label_col)
    model = rf.fit(train_data)
    return model, train_data, test_data  

# Function to get sorted feature importance
def get_feature_importance(rf_model, feature_cols):
    importances = rf_model.featureImportances
    feature_importance_list = [(feature, importances[idx]) for idx, feature in enumerate(feature_cols)]
    feature_importance_list.sort(key=lambda x: x[1], reverse=True)
    return feature_importance_list 

# Function to find the best feature set by RMSE
def find_best_feature_set(data, label_col='glucose'):
    feature_cols = data.columns[:-1]
    initial_features = feature_cols.copy()
    best_rmse = float('inf')
    best_data = None

    rmse_list = []

    # Initial model to get feature importances
    initial_model, _, _ = train_random_forest_model(data, initial_features, label_col)
    feature_importances = get_feature_importance(initial_model, initial_features)

    for iteration in range(len(feature_cols) - 2):
        model, train_data, test_data = train_random_forest_model(data, initial_features, label_col)
        predictions = model.transform(test_data)
        
        evaluator = RegressionEvaluator(labelCol=label_col, predictionCol="prediction", metricName="rmse")
        current_rmse = evaluator.evaluate(predictions)
        rmse_list.append((len(initial_features), current_rmse))

        if current_rmse < best_rmse:
            best_rmse = current_rmse
            best_features = initial_features.copy()
            best_data = train_data.select(initial_features)

        # Remove the least important feature based on initial importances
        initial_features.remove(feature_importances[-1][0])
        feature_importances.pop(-1)  # Update the importance list
        data = data.select(*initial_features, label_col)  # Update the data to exclude the least important feature
    
    return best_data, feature_importances, rmse_list

# %%
# # Example usage:
# myData = df 
# best_data, feature_importances, rmses = find_best_feature_set(myData)

# # Print results
# print("Feature Importances:")
# for importance in feature_importances:
#     print(importance)

# print("\nRMSE by Iteration:")
# for rmse in rmses:
#     print(rmse)

# best_data.show()

# %%
# initial_model, _, _ = train_random_forest_model(myData, myData.columns[:-1])
# feature_importances = get_feature_importance(initial_model, myData.columns[:-1])

# %%
# print("Feature Importances:")
# for importance in feature_importances:
#     print(importance)

# %%
# import pandas as pd

# # Convert feature importances and RMSE list to DataFrame
# feature_importance_df = pd.DataFrame(feature_importances, columns=['Feature', 'Importance'])
# rmse_df = pd.DataFrame(rmses, columns=['Number of Features', 'RMSE'])

# # Save DataFrames to CSV for use in papers
# feature_importance_df.to_csv("feature_importances.csv", index=False)
# rmse_df.to_csv("rmse_by_iteration.csv", index=False)

# # Optional: Save to LaTeX (if you're using LaTeX for your paper)
# feature_importance_df.to_latex("feature_importances.tex", index=False)
# rmse_df.to_latex("rmse_by_iteration.tex", index=False)

# # Print DataFrames to screen (optional, for quick verification)
# print("Feature Importances:\n", feature_importance_df)
# print("\nRMSE by Iteration:\n", rmse_df)

# %%
# best_feature_columns = best_data.columns

# # Convert column names to a DataFrame
# best_features_df = pd.DataFrame(best_feature_columns, columns=['Best Features'])

# # Save the DataFrame to CSV
# best_features_df.to_csv("best_features.csv", index=False)

# %%
def separate_datasets_by_glucose(dataset, glucose_threshold=5.5):
    """
    Separates the dataset into two datasets based on the second year glucose number using PySpark.

    Args:
        dataset (pyspark.sql.DataFrame): The original dataset.
        glucose_threshold (float): The threshold value for separating the datasets
            based on the second year glucose number. Default is 6.1.

    Returns:
        tuple: A tuple containing two datasets:
            - normal_dataset (pyspark.sql.DataFrame): Dataset with glucose_year2 < glucose_threshold.
            - abnormal_dataset (pyspark.sql.DataFrame): Dataset with glucose_year2 >= glucose_threshold.
    """
    normal_dataset = dataset.filter(dataset['sy_glucose'] < glucose_threshold)
    abnormal_dataset = dataset.filter(dataset['sy_glucose'] >= glucose_threshold)
    return normal_dataset, abnormal_dataset

# %%
normal_people, abnormal_people = separate_datasets_by_glucose(df)


## Normal People Feature Selection
best_data, feature_importances, rmses = find_best_feature_set(normal_people)


print("\nRMSE by Iteration:")
for rmse in rmses:
    print(rmse)

best_data.show()
initial_model, _, _ = train_random_forest_model(normal_people, normal_people.columns[:-1])
feature_importances = get_feature_importance(initial_model, normal_people.columns[:-1])

print("Feature Importances:")
for importance in feature_importances:
    print(importance)
# Out:
# RMSE by Iteration:
# (159, 0.32452126299610096)
# (158, 0.3246438279471127)
# (157, 0.3219097692089593)
# (156, 0.3181887567882844)
# (155, 0.3199457893314053)
# (154, 0.327116450451998)
# (153, 0.32289424413421863)
# (152, 0.3229180206843173)
# (151, 0.324522980062626)
# (150, 0.3217675501701615)
# (149, 0.32276705821512114)
# (148, 0.3213822182768603)
# (147, 0.3196356072171749)
# (146, 0.32505463095733744)
# (145, 0.32109491548246016)
# (144, 0.319315482713642)
# (143, 0.31864555112166)
# (142, 0.3202630283668023)
# (141, 0.32602819090989893)
# (140, 0.326439907607703)
# (139, 0.32745715903377176)
# (138, 0.3244240909078629)
# (137, 0.32301491785759795)
# (136, 0.3251329591174945)
# (135, 0.3225575224860505)
# (134, 0.3184169646121533)
# (133, 0.31664853061536835)
# (132, 0.32063448262302463)
# (131, 0.3144129773743319)
# (130, 0.31531202276652176)
# (129, 0.3147808813403811)
# (128, 0.31773000176758254)
# (127, 0.31960510186046553)
# (126, 0.321097041795312)
# (125, 0.3174686104342564)
# (124, 0.32149315610349366)
# (123, 0.31695785311398994)
# (122, 0.3167200896735552)
# (121, 0.31926767396987227)
# (120, 0.31487365738982387)
# (119, 0.31937834841740426)
# (118, 0.3161733989607298)
# (117, 0.31798880910917515)
# (116, 0.31762952135721073)
# (115, 0.31563556537138365)
# (114, 0.32037651773734993)
# (113, 0.3172561773779131)
# (112, 0.31777210118266214)
# (111, 0.31408601450991974)
# (110, 0.32023235464839483)
# (109, 0.3169577281777681)
# (108, 0.3145925620206195)
# (107, 0.32059469215597836)
# (106, 0.31872270297061933)
# (105, 0.31552906261050667)
# (104, 0.3158354694395773)
# (103, 0.3177996695725321)
# (102, 0.3205468374340333)
# (101, 0.31907507048312655)
# (100, 0.3168939705507703)
# (99, 0.3171423453877506)
# (98, 0.3140269767884726)
# (97, 0.31536200639052864)
# (96, 0.31825672283153383)
# (95, 0.3174129071650248)
# (94, 0.31964984310215355)
# (93, 0.3192351692223749)
# (92, 0.3159727211805022)
# (91, 0.3198045694408377)
# (90, 0.3228095347922904)
# (89, 0.3203549886388189)
# (88, 0.32015522604662366)
# (87, 0.3168683248721244)
# (86, 0.3167517406189093)
# (85, 0.3171910288154548)
# (84, 0.3185713017787425)
# (83, 0.32027780331298267)
# (82, 0.3169391249702136)
# (81, 0.31951855161878195)
# (80, 0.3170972221615804)
# (79, 0.31494845813119454)
# (78, 0.3178508647905984)
# (77, 0.3199823715155846)
# (76, 0.3150609364947398)
# (75, 0.31750945266145447)
# (74, 0.31715501759855524)
# (73, 0.3172186231764034)
# (72, 0.31462981260176043)
# (71, 0.3166791314752585)
# (70, 0.3153983611451979)
# (69, 0.3186976533234959)
# (68, 0.3164713474092091)
# (67, 0.31549711810322134)
# (66, 0.32026104621564416)
# (65, 0.31838891679406595)
# (64, 0.3193464006175225)
# (63, 0.31832632655343257)
# (62, 0.3180985748641451)
# (61, 0.31939553887844746)
# (60, 0.3174164632486255)
# (59, 0.3193426520731579)
# (58, 0.31748133357980973)
# (57, 0.3172278168138071)
# (56, 0.3168388591255485)
# (55, 0.31977047637587785)
# (54, 0.3187257513694728)
# (53, 0.3160826186082119)
# (52, 0.31382174904068927)
# (51, 0.3186656484843253)
# (50, 0.32036676602711217)
# (49, 0.3160133619240127)
# (48, 0.3157505887243576)
# (47, 0.31816742546159366)
# (46, 0.31466486161175694)
# (45, 0.3167666463038322)
# (44, 0.3169182755000762)
# (43, 0.31568549127940965)
# (42, 0.31775629007506284)
# (41, 0.3190554809408775)
# (40, 0.31897788377550335)
# (39, 0.3182632328863477)
# (38, 0.3155800040962374)
# (37, 0.30851946024372273)
# (36, 0.3130903853215007)
# (35, 0.3160766238669487)
# (34, 0.31380462000226617)
# (33, 0.30998833820973387)
# (32, 0.3104504791019094)
# (31, 0.3082751840853816)
# (30, 0.31069779835617)
# (29, 0.3091888504120474)
# (28, 0.311810829291568)
# (27, 0.31057069741206506)
# (26, 0.31033296695061663)
# (25, 0.3054134900402696)
# (24, 0.32373979722154667)
# (23, 0.32318599989254176)
# (22, 0.3243202683611789)
# (21, 0.32446122544154166)
# (20, 0.3213675348996394)
# (19, 0.3128601095543127)
# (18, 0.30947163449737775)
# (17, 0.3123266336370085)
# (16, 0.312882992711157)
# (15, 0.31086626420485)
# (14, 0.30809540917372685)
# (13, 0.2880946877580768)
# (12, 0.2900784768100516)
# (11, 0.2899133595618586)
# (10, 0.29301996378301015)
# (9, 0.3067012129312559)
# (8, 0.30192787430795837)
# (7, 0.3045219780375458)
# (6, 0.30116277406087105)
# (5, 0.3009232099419296)
# (4, 0.3022468593110164)
# (3, 0.3144429906673072)
# 24/05/15 10:25:56 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +---+----------+-------------+---------------+---------------------------------------+------------+------------+------------------------------+----------+---------------+---------------+------------+-------------+
# |age|fy_glucose|fy_creatinine|fy_trioxypurine|fy_high_density_lipoprotein_cholesterol|fy_3000_left|fy_4000_left|sy_absolute_value_of_basophils|sy_glucose|sy_trioxypurine|sy_triglyceride|sy_4000_left|sy_2000_right|
# +---+----------+-------------+---------------+---------------------------------------+------------+------------+------------------------------+----------+---------------+---------------+------------+-------------+
# | 24|      0.15|  0.429357798|    0.410060976|                            0.384297521| 0.117647059| 0.052631579|                   0.176470588|       4.9|    0.317230274|    0.029863481| 0.111111111|        0.125|
# | 24|      0.16|  0.422018349|    0.410060976|                            0.483471074| 0.058823529| 0.052631579|                   0.176470588|       5.1|    0.449275362|    0.077645051| 0.222222222|         0.25|
# | 25|      0.15|  0.367889908|    0.347560976|                            0.190082645| 0.235294118| 0.210526316|                   0.176470588|       5.3|    0.473429952|    0.324232082| 0.222222222|       0.1875|
# | 25|      0.16|  0.447706422|    0.478658537|                            0.260330579| 0.235294118| 0.210526316|                   0.117647059|       5.3|    0.429951691|    0.032423208| 0.055555556|       0.0625|
# | 26|      0.12|  0.282568807|     0.24847561|                            0.392561983| 0.235294118| 0.210526316|                   0.058823529|       5.2|    0.241545894|     0.03668942| 0.111111111|       0.1875|
# | 26|      0.12|  0.293577982|    0.426829268|                            0.285123967| 0.117647059| 0.105263158|                   0.235294118|       4.5|    0.323671498|    0.124573379| 0.111111111|        0.125|
# | 26|      0.12|  0.422018349|    0.286585366|                            0.314049587| 0.235294118| 0.210526316|                   0.176470588|       5.1|     0.32689211|    0.074232082| 0.166666667|         0.25|
# | 26|      0.13|  0.394495413|    0.458841463|                            0.305785124| 0.176470588| 0.157894737|                   0.352941176|       5.0|    0.487922705|    0.031569966| 0.222222222|        0.125|
# | 26|      0.13|  0.403669725|    0.342987805|                            0.157024793| 0.117647059| 0.052631579|                   0.235294118|       5.3|    0.429951691|    0.211604096| 0.111111111|       0.0625|
# | 26|      0.13|  0.425688073|    0.423780488|                            0.280991736| 0.117647059| 0.157894737|                   0.058823529|       4.7|    0.426731079|    0.079351536| 0.111111111|        0.125|
# | 26|      0.13|   0.47706422|    0.362804878|                            0.342975207| 0.058823529| 0.105263158|                   0.176470588|       5.1|     0.46215781|    0.012798635| 0.166666667|       0.0625|
# | 26|      0.16|   0.38440367|    0.300304878|                            0.252066116| 0.176470588| 0.157894737|                   0.117647059|       4.9|    0.264090177|    0.100682594| 0.166666667|       0.1875|
# | 26|      0.17|  0.366972477|    0.420731707|                            0.479338843| 0.117647059| 0.105263158|                   0.117647059|       5.3|    0.314009662|    0.028156997| 0.166666667|       0.1875|
# | 26|      0.17|  0.417431193|    0.268292683|                             0.41322314| 0.176470588| 0.157894737|                   0.117647059|       5.2|    0.355877617|    0.097269625| 0.166666667|        0.125|
# | 26|      0.17|  0.495412844|    0.429878049|                            0.305785124| 0.235294118| 0.157894737|                   0.176470588|       5.4|    0.384863124|    0.029010239| 0.055555556|        0.125|
# | 26|      0.18|  0.241284404|    0.199695122|                            0.338842975| 0.058823529| 0.052631579|                   0.058823529|       5.1|     0.22705314|    0.062286689| 0.111111111|        0.125|
# | 26|      0.18|  0.357798165|    0.588414634|                            0.231404959| 0.176470588| 0.157894737|                   0.235294118|       5.3|    0.584541063|    0.325085324| 0.222222222|       0.1875|
# | 26|      0.19|  0.375229358|     0.43902439|                            0.421487603| 0.058823529| 0.052631579|                   0.117647059|       4.7|    0.339774557|    0.065699659|         0.0|          0.0|
# | 27|      0.06|          0.4|    0.365853659|                            0.326446281| 0.117647059| 0.105263158|                   0.176470588|       4.6|     0.29468599|    0.044368601| 0.222222222|       0.1875|
# | 27|      0.08|  0.416513761|     0.24695122|                            0.318181818| 0.176470588| 0.105263158|                   0.352941176|       4.6|    0.270531401|    0.089590444| 0.166666667|       0.1875|
# +---+----------+-------------+---------------+---------------------------------------+------------+------------+------------------------------+----------+---------------+---------------+------------+-------------+
# only showing top 20 rows
#
# Feature Importances:
# ('fy_glucose', 0.28757576044847144)
# ('sy_glucose', 0.18535338538657586)
# ('age', 0.027423599861294164)
# ('fy_3000_left', 0.014273427307278458)
# ('sy_4000_left', 0.014253961147102565)
# ('sy_absolute_value_of_basophils', 0.012558808951912269)
# ('sy_triglyceride', 0.012252783155269365)
# ('sy_trioxypurine', 0.012120795576090191)
# ('fy_4000_left', 0.01208960927015711)
# ('fy_creatinine', 0.010352969040919324)
# ('fy_trioxypurine', 0.009340130840342518)
# ('fy_high_density_lipoprotein_cholesterol', 0.0092691760449259)
# ('sy_2000_right', 0.009219360367923419)
# ('fy_mean_corpuscular_hemoglobin_concentration', 0.009033094975944499)
# ('sy_3000_right', 0.008853524162631595)
# ('sy_absolute_eosinophil_count', 0.008787453569607468)
# ('sy_carbamide', 0.008785025657910046)
# ('fy_apolipoprotein_B100', 0.007717325119418202)
# ('fy_free_prostate_specific_antigen', 0.00754743625205067)
# ('fy_absolute_eosinophil_count', 0.007509675669427488)
# ('sy_proportion', 0.007335097892805578)
# ('fy_pct', 0.007255869973160945)
# ('sy_1000_left', 0.006951546710415837)
# ('fy_carbamide', 0.006477516808263093)
# ('fy_percentage_of_lymphocytes', 0.006233679106211481)
# ('sy_red_cell_assembling_index', 0.006098049638095841)
# ('fy_diastolic_blood_pressure_low', 0.005833564075300451)
# ('fy_the_K_value_of_the_ESR_equation', 0.0057731285791662755)
# ('sy_erythrocyte', 0.00557258695212751)
# ('sy_systolic_blood_pressure_high', 0.0052505142841877605)
# ('fy_low_density_lipoprotein_cholesterin', 0.0051648155348128005)
# ('fy_4000_right', 0.004880325575768031)
# ('fy_calcium', 0.004854016897295507)
# ('sy_millet_grass_millet_c', 0.00475527164636523)
# ('sy_a_hydroxybutyrate_dehydrogenase', 0.004683883727758799)
# ('sy_apolipoprotein_B100', 0.004623762256183949)
# ('fy_a_hydroxybutyrate_dehydrogenase', 0.004612418227647854)
# ('sy_absolute_neutrophil_count', 0.0045675763459709475)
# ('fy_systolic_blood_pressure_high', 0.004544666216195436)
# ('fy_absolute_value_of_monocytes', 0.0044231840852456215)
# ('fy_free_T4', 0.004331535923367617)
# ('sy_ph_value', 0.004323671731287882)
# ('sy_total_bilirubin', 0.004218330264384062)
# ('sy_6000_left', 0.004105502505075673)
# ('sy_total_cholesterol', 0.004049729222394884)
# ('fy_triglyceride', 0.00401073409710285)
# ('sy_hemoglobin', 0.003959768984239833)
# ('sy_ESR_blood_sedimentation', 0.003862583393011965)
# ('fy_total_protein', 0.003849695383466029)
# ('sy_total_protein', 0.0036735465195005808)
# ('fy_1000_right', 0.003633610924986083)
# ('fy_millet_grass_millet_c', 0.0035991291316481394)
# ('fy_ph_value', 0.003556352629169295)
# ('fy_carcino_embryonic_antigen', 0.003547540473068107)
# ('sy_diastolic_blood_pressure_low', 0.003513279093657023)
# ('sy_sreatine_kinase_isoenzyme', 0.0035046253339487765)
# ('sy_neutrophilic_granulocyte_percentage', 0.003502996084874474)
# ('sy_phosphorus', 0.0034649286348928774)
# ('sy_lactic_dehydrogenase', 0.0034001948736289396)
# ('sy_apolipoprotein_ai', 0.0033808194060941624)
# ('sy_alpha_fetoprotein', 0.003274662432868813)
# ('sy_whole_blood_viscosity_values_2Pas_shear_rate30s', 0.00325049382560782)
# ('sy_mean_corpuscular_hemoglobin_concentration', 0.0032263109923363407)
# ('sy_high_density_low_density', 0.0031165126762589088)
# ('sy_total_prostate_specific_antigen', 0.0030689180754218293)
# ('fy_creatine_phosphate_kinase', 0.0030648986191065047)
# ('sy_r_glutamyl_transpeptidase', 0.0030453539519061704)
# ('sy_globulin', 0.0029261237655428393)
# ('sy_4000_right', 0.0028805070067091563)
# ('fy_hematocrit56', 0.002878962345336711)
# ('fy_proportion', 0.0028636219586420644)
# ('fy_mean_corpuscular_volume', 0.002750917259507949)
# ('fy_whole_blood_viscosity_values_2Pas_shear_rate30s', 0.00266265085647608)
# ('fy_direct_bilirubin', 0.002643100146694541)
# ('fy_globulin', 0.0025893168312408196)
# ('sy_500_right', 0.0025623901501115377)
# ('sy_lymphocyte_number', 0.002558921761463092)
# ('sy_the_K_value_of_the_ESR_equation', 0.0024674848710848807)
# ('fy_total_prostate_specific_antigen', 0.0024532166257938116)
# ('sy_free_T4', 0.0023984367091460417)
# ('sy_blood_platelet', 0.0023866948959262407)
# ('fy_glutamic_oxalacetic_transaminase', 0.002350420130196078)
# ('fy_2000_left', 0.002318909576095828)
# ('sy_low_density_lipoprotein_cholesterin', 0.002306741854033449)
# ('fy_whole_blood_viscosity_values_1pas_the_shear_rate_200s', 0.002297161354708541)
# ('fy_apolipoprotein_ai', 0.0022438534132149784)
# ('sy_high_density_lipoprotein_cholesterol', 0.0022390914687945218)
# ('sy_direct_bilirubin', 0.00222448145733691)
# ('sy_creatinine', 0.002221993829324509)
# ('sy_calcium', 0.0022097968714136934)
# ('fy_lactic_dehydrogenase', 0.002209180637503302)
# ('sy_red_blood_cell_distribution_width_CV', 0.002147812759204544)
# ('sy_carcino_embryonic_antigen', 0.0021350362744436174)
# ('fy_mean_platelet_volume', 0.002085758999949086)
# ('fy_lymphocyte_number', 0.002058165315756878)
# ('sy_alkaline_phosphatase', 0.0020153509742726473)
# ('fy_whole_blood_viscosity_values_4Pas_shear_rate1s', 0.0019903532457347982)
# ('fy_free_T3', 0.0019182013762676145)
# ('fy_red_blood_cell_distribution_width_SD', 0.0019103564111759858)
# ('fy_hemoglobin', 0.0018658379619473646)
# ('sy_red_blood_cell_distribution_width_SD', 0.0018645818741059386)
# ('sy_albumin', 0.0018511408317834221)
# ('fy_absolute_neutrophil_count', 0.001785155958121855)
# ('fy_ESR_blood_sedimentation', 0.0016693781197595228)
# ('fy_percentage_of_monocytes', 0.001582840885256638)
# ('sy_2000_left', 0.0015282052957685227)
# ('sy_albumin_globulin', 0.001511953536741843)
# ('fy_6000_right', 0.0014107030223483076)
# ('fy_6000_left', 0.0014033072128189243)
# ('fy_whole_blood_viscosity_values_3Pas_shear_rate5s', 0.001353097584366373)
# ('sy_mean_platelet_volume', 0.0013509445190325738)
# ('fy_thyroid_stimulating_hormone', 0.001316232785344628)
# ('sy_percentage_of_lymphocytes', 0.0013075816110278843)
# ('sy_mean_corpuscular_hemoglobin', 0.001297428051128422)
# ('fy_albumin_globulin', 0.001207235236177066)
# ('sy_hemameba', 0.0011568978997894101)
# ('sy_creatine_phosphate_kinase', 0.001141845065801044)
# ('sy_whole_blood_viscosity_values_4Pas_shear_rate1s', 0.001067267193615819)
# ('fy_r_glutamyl_transpeptidase', 0.0010605494483184284)
# ('fy_glutamic_pyruvic_transaminase', 0.0010516935498640994)
# ('sy_thyroid_stimulating_hormone', 0.0009956109416394436)
# ('sy_1000_right', 0.000981972427039604)
# ('sy_pct', 0.0009645852983656327)
# ('sy_mean_corpuscular_volume', 0.0009499887436157827)
# ('fy_total_cholesterol', 0.0009134787121833232)
# ('sy_500_left', 0.0008000964095104322)
# ('sy_free_prostate_specific_antigen', 0.0007503274203002231)
# ('sy_hematocrit56', 0.000730180937693687)
# ('fy_red_cell_assembling_index', 0.0006889051339941266)
# ('sy_free_T3', 0.0006189269062849924)
# ('fy_mean_corpuscular_hemoglobin', 0.0006099627269449867)
# ('sy_glutamic_pyruvic_transaminase', 0.0005607372319620722)
# ('fy_sreatine_kinase_isoenzyme', 0.0005039627190697524)
# ('sy_whole_blood_viscosity_values_1pas_the_shear_rate_200s', 0.00046709396248331096)
# ('fy_neutrophilic_granulocyte_percentage', 0.00044256925994711643)
# ('fy_3000_right', 0.0003523423892116913)
# ('fy_alkaline_phosphatase', 0.00031423418454777315)
# ('fy_blood_platelet', 0.0002818081764642224)
# ('fy_erythrocyte', 0.0002742939718289981)
# ('fy_high_density_low_density', 0.00018389681327205367)
# ('fy_hemameba', 0.00013704366267528674)
# ('sy_platelet_distribution_width', 1.9344832428256293e-05)
# ('sy_whole_blood_viscosity_values_3Pas_shear_rate5s', 1.819774595219223e-05)
# ('sy_absolute_value_of_monocytes', 7.048094826519997e-06)
# ('fy_absolute_value_of_basophils', 0.0)
# ('fy_red_blood_cell_distribution_width_CV', 0.0)
# ('fy_platelet_distribution_width', 0.0)
# ('fy_large_platelet_ratio', 0.0)
# ('fy_albumin', 0.0)
# ('fy_total_bilirubin', 0.0)
# ('fy_alpha_fetoprotein', 0.0)
# ('fy_500_left', 0.0)
# ('fy_1000_left', 0.0)
# ('fy_500_right', 0.0)
# ('fy_2000_right', 0.0)
# ('sy_large_platelet_ratio', 0.0)
# ('sy_glutamic_oxalacetic_transaminase', 0.0)
# ('sy_3000_left', 0.0)
# ('sy_6000_right', 0.0)

# %%
import pandas as pd

# Convert feature importances and RMSE list to DataFrame
feature_importance_df = pd.DataFrame(feature_importances, columns=['Feature', 'Importance'])
rmse_df = pd.DataFrame(rmses, columns=['Number of Features', 'RMSE'])

# Save DataFrames to CSV for use in papers
feature_importance_df.to_csv("feature_importances.csv", index=False)
rmse_df.to_csv("rmse_by_iteration.csv", index=False)

# Optional: Save to LaTeX (if you're using LaTeX for your paper)
feature_importance_df.to_latex("feature_importances.tex", index=False)
rmse_df.to_latex("rmse_by_iteration.tex", index=False)

# Print DataFrames to screen (optional, for quick verification)
print("Feature Importances:\n", feature_importance_df)
print("\nRMSE by Iteration:\n", rmse_df)
best_feature_columns = best_data.columns

# Convert column names to a DataFrame
best_features_df = pd.DataFrame(best_feature_columns, columns=['Best Features'])

# Save the DataFrame to CSV
best_features_df.to_csv("best_features.csv", index=False)
# Out:
# Feature Importances:
#                                   Feature  Importance
# 0                             fy_glucose    0.287576
# 1                             sy_glucose    0.185353
# 2                                    age    0.027424
# 3                           fy_3000_left    0.014273
# 4                           sy_4000_left    0.014254
# ..                                   ...         ...
# 154                        fy_2000_right    0.000000
# 155              sy_large_platelet_ratio    0.000000
# 156  sy_glutamic_oxalacetic_transaminase    0.000000
# 157                         sy_3000_left    0.000000
# 158                        sy_6000_right    0.000000
#
# [159 rows x 2 columns]
#
# RMSE by Iteration:
#       Number of Features      RMSE
# 0                   159  0.324521
# 1                   158  0.324644
# 2                   157  0.321910
# 3                   156  0.318189
# 4                   155  0.319946
# ..                  ...       ...
# 152                   7  0.304522
# 153                   6  0.301163
# 154                   5  0.300923
# 155                   4  0.302247
# 156                   3  0.314443
#
# [157 rows x 2 columns]

# %%
## Abnormal People feature selection 
# Example usage:
best_data, feature_importances, rmses = find_best_feature_set(abnormal_people)

# Print results
print("Feature Importances:")
for importance in feature_importances:
    print(importance)

print("\nRMSE by Iteration:")
for rmse in rmses:
    print(rmse)

best_data.show()
initial_model, _, _ = train_random_forest_model(abnormal_people, abnormal_people.columns[:-1])
feature_importances = get_feature_importance(initial_model, abnormal_people.columns[:-1])

print("Feature Importances:")
for importance in feature_importances:
    print(importance)
# Out:
# Feature Importances:
# ('fy_glucose', 0.2986515227498077)
# ('sy_glucose', 0.1593994611398996)
#
# RMSE by Iteration:
# (159, 0.9955741080607478)
# (158, 0.9903305882331017)
# (157, 0.9893400812222163)
# (156, 0.9634036693998633)
# (155, 0.9854409908292406)
# (154, 0.9604134051560624)
# (153, 0.9627342989245797)
# (152, 0.9728766366764358)
# (151, 0.981579993713069)
# (150, 1.0033754280804585)
# (149, 0.9581916096170493)
# (148, 1.0036881790082117)
# (147, 0.9882688302807698)
# (146, 0.9705135882504436)
# (145, 0.9643586887745659)
# (144, 0.9832310256686964)
# (143, 0.9840750447636393)
# (142, 0.9930056694892901)
# (141, 0.9509899139004121)
# (140, 0.9371858704517798)
# (139, 0.9985207005472866)
# (138, 0.9859488454306121)
# (137, 0.9984032765618044)
# (136, 1.002664582490392)
# (135, 1.0085871880185986)
# (134, 0.9920431347077772)
# (133, 0.9953691089585951)
# (132, 0.974143952765751)
# (131, 0.9519895917709076)
# (130, 0.95322275095418)
# (129, 1.0225799106532751)
# (128, 0.9849514932720395)
# (127, 0.9687256034425996)
# (126, 0.9758392461430682)
# (125, 0.9774960603422177)
# (124, 0.988345420556376)
# (123, 0.9916182148341787)
# (122, 0.960652338997811)
# (121, 0.9634065215350573)
# (120, 0.9626150613813004)
# (119, 0.9747078667846625)
# (118, 0.9787987733259922)
# (117, 1.0039160927421662)
# (116, 0.9899060910060185)
# (115, 1.0092043860315807)
# (114, 1.020539489329732)
# (113, 1.013176039771429)
# (112, 1.0024350790180927)
# (111, 0.9953032727250438)
# (110, 1.0236451139108873)
# (109, 1.027182970575442)
# (108, 1.0074700010803026)
# (107, 1.0134118232188398)
# (106, 1.0037228016194195)
# (105, 1.018603529102025)
# (104, 1.0014384320694873)
# (103, 0.9999105223079595)
# (102, 0.9901549116297781)
# (101, 0.9967832479870111)
# (100, 0.9880030600833247)
# (99, 0.9985241610768176)
# (98, 0.9741570169500262)
# (97, 0.9620627067041251)
# (96, 1.0055808257563723)
# (95, 0.9643083889148538)
# (94, 0.9705873158534258)
# (93, 0.9477209964710519)
# (92, 0.936511222872295)
# (91, 0.9340254996141115)
# (90, 0.9400134708918713)
# (89, 0.9396132260574596)
# (88, 0.9792837377798587)
# (87, 0.9882749015107786)
# (86, 0.9855434809580984)
# (85, 0.9792619931178856)
# (84, 1.0138191365732558)
# (83, 0.9957249019026507)
# (82, 0.9865662577706319)
# (81, 0.9872845406307446)
# (80, 1.0024796090009203)
# (79, 0.9704911047637166)
# (78, 0.9623190955266973)
# (77, 0.9682666780989875)
# (76, 0.962268717238122)
# (75, 0.9603589951269333)
# (74, 0.9972666449112487)
# (73, 0.9760287390225394)
# (72, 0.9837853786202372)
# (71, 0.9524466042575964)
# (70, 0.9885844021498116)
# (69, 0.9767305668239654)
# (68, 0.9818362739571515)
# (67, 0.9755105647617565)
# (66, 0.9946136290262333)
# (65, 0.9711695393876957)
# (64, 1.0073896989320479)
# (63, 0.9499303775451123)
# (62, 0.9783745274477669)
# (61, 0.9876649519623826)
# (60, 0.9727490056682028)
# (59, 0.9808236399003587)
# (58, 0.9691380324786802)
# (57, 0.9775622826635353)
# (56, 0.9709855693941372)
# (55, 0.9830170248696416)
# (54, 0.9718436552093381)
# (53, 0.9945583627476007)
# (52, 0.9913670815042549)
# (51, 0.9721229524099512)
# (50, 0.9552712830599918)
# (49, 0.9898599123054953)
# (48, 0.9652301857258124)
# (47, 0.9749599810218597)
# (46, 1.0043641183959249)
# (45, 0.9479550812138452)
# (44, 0.9990959687217562)
# (43, 0.9794067331065215)
# (42, 0.9483144397579463)
# (41, 0.9656486615722866)
# (40, 0.9681454833492986)
# (39, 0.9690200419702576)
# (38, 0.9627547719777836)
# (37, 0.9853801722498827)
# (36, 0.9643130913725044)
# (35, 0.9673677174584909)
# (34, 1.009338460261041)
# (33, 0.6406072722823931)
# (32, 0.5691940167152219)
# (31, 0.6255937728710533)
# (30, 0.6253974020973975)
# (29, 0.6472008779432011)
# (28, 0.5829745101493489)
# (27, 0.5717150866984057)
# (26, 0.643109946802149)
# (25, 0.627868378782742)
# (24, 0.6233220404145838)
# (23, 0.6304011047804041)
# (22, 0.6242621550298758)
# (21, 0.6174891460796821)
# (20, 1.0568977493647795)
# (19, 1.0368613282331802)
# (18, 1.0537004524852547)
# (17, 1.0484531920295546)
# (16, 1.071995805598401)
# (15, 0.505580250629438)
# (14, 0.5153482723467275)
# (13, 0.45509156822026947)
# (12, 0.5262762200817347)
# (11, 0.43644209290503516)
# (10, 0.443561800780862)
# (9, 0.4407317525049518)
# (8, 0.4932772408349254)
# (7, 0.5140234244754663)
# (6, 0.4123991239450847)
# (5, 0.45079648593148836)
# (4, 0.5121685964985245)
# (3, 0.5358602814993187)
# +--------------------------------------------------------+--------------------------------------------------+----------+------------+-------------+----------+
# |fy_whole_blood_viscosity_values_1pas_the_shear_rate_200s|fy_whole_blood_viscosity_values_2Pas_shear_rate30s|fy_glucose|fy_carbamide|fy_proportion|sy_glucose|
# +--------------------------------------------------------+--------------------------------------------------+----------+------------+-------------+----------+
# |                                             0.011695906|                                       0.006072874|      0.15| 0.229216152|  0.619047619|       5.5|
# |                                             0.011695906|                                       0.012145749|      0.08| 0.741092637|  0.571428571|       5.8|
# |                                             0.011695906|                                       0.036437247|      0.16| 0.314726841|  0.404761905|       5.5|
# |                                              0.01754386|                                       0.002024291|      0.15| 0.287410926|  0.642857143|       5.7|
# |                                             0.023391813|                                       0.006072874|      0.18| 0.429928741|  0.547619048|       5.5|
# |                                             0.023391813|                                       0.006072874|      0.24|  0.35391924|  0.666666667|       5.8|
# |                                             0.023391813|                                       0.012145749|      0.16| 0.236342043|  0.666666667|       5.8|
# |                                             0.023391813|                                        0.01417004|      0.16| 0.800475059|  0.761904762|       5.7|
# |                                             0.029239766|                                       0.004048583|      0.18| 0.188836105|  0.428571429|       5.7|
# |                                             0.029239766|                                       0.010121457|      0.18| 0.509501188|  0.714285714|       5.5|
# |                                             0.029239766|                                       0.012145749|      0.13| 0.143705463|  0.357142857|       5.5|
# |                                             0.029239766|                                       0.018218623|      0.22| 0.350356295|  0.476190476|       5.7|
# |                                             0.029239766|                                       0.020242915|      0.14| 0.403800475|  0.785714286|       5.5|
# |                                             0.029239766|                                       0.022267206|      0.13| 0.262470309|   0.69047619|       5.5|
# |                                             0.035087719|                                       0.004048583|      0.18| 0.539192399|  0.595238095|       6.1|
# |                                             0.035087719|                                       0.006072874|      0.15| 0.275534442|  0.571428571|       5.7|
# |                                             0.035087719|                                       0.006072874|      0.16| 0.211401425|  0.738095238|       5.6|
# |                                             0.035087719|                                       0.010121457|      0.21| 0.217339667|          0.5|       5.9|
# |                                             0.035087719|                                       0.012145749|      0.17| 0.452494062|  0.476190476|       6.0|
# |                                             0.035087719|                                       0.012145749|      0.18| 0.328978622|  0.619047619|       5.6|
# +--------------------------------------------------------+--------------------------------------------------+----------+------------+-------------+----------+
# only showing top 20 rows
#
# Feature Importances:
# ('fy_glucose', 0.2986515227498077)
# ('sy_glucose', 0.1593994611398996)
# ('fy_whole_blood_viscosity_values_2Pas_shear_rate30s', 0.03667449457606266)
# ('fy_carbamide', 0.02552328660367194)
# ('fy_whole_blood_viscosity_values_1pas_the_shear_rate_200s', 0.021411491504924517)
# ('fy_proportion', 0.019527665044258957)
# ('sy_erythrocyte', 0.019512102908445298)
# ('sy_blood_platelet', 0.015388303027861242)
# ('fy_lactic_dehydrogenase', 0.015253254751996908)
# ('sy_free_T4', 0.014711186165671443)
# ('sy_whole_blood_viscosity_values_2Pas_shear_rate30s', 0.01402210368554636)
# ('fy_creatine_phosphate_kinase', 0.013334185773425085)
# ('fy_alkaline_phosphatase', 0.012955111825616976)
# ('sy_total_cholesterol', 0.01242122038364719)
# ('sy_creatinine', 0.011722528093621808)
# ('age', 0.010357299717251807)
# ('sy_r_glutamyl_transpeptidase', 0.00961944054223002)
# ('sy_absolute_eosinophil_count', 0.009287866202839673)
# ('fy_glutamic_pyruvic_transaminase', 0.009260456321056666)
# ('sy_the_K_value_of_the_ESR_equation', 0.009159493754676009)
# ('fy_neutrophilic_granulocyte_percentage', 0.008760392644927825)
# ('fy_albumin_globulin', 0.008677941200812955)
# ('fy_blood_platelet', 0.008574955831610269)
# ('sy_4000_right', 0.008131176753397185)
# ('sy_absolute_value_of_basophils', 0.007889585875823701)
# ('sy_a_hydroxybutyrate_dehydrogenase', 0.007465458588361181)
# ('fy_trioxypurine', 0.007111540733608197)
# ('sy_calcium', 0.0068997918634740646)
# ('sy_phosphorus', 0.006432995361325043)
# ('fy_red_cell_assembling_index', 0.006404715246559906)
# ('fy_apolipoprotein_ai', 0.006341160721297626)
# ('fy_systolic_blood_pressure_high', 0.006271791029697174)
# ('fy_absolute_neutrophil_count', 0.005997199143422535)
# ('fy_diastolic_blood_pressure_low', 0.005985335086296496)
# ('sy_1000_left', 0.0059822913416950575)
# ('fy_glutamic_oxalacetic_transaminase', 0.0053320615254983)
# ('fy_whole_blood_viscosity_values_4Pas_shear_rate1s', 0.004986180963331165)
# ('sy_thyroid_stimulating_hormone', 0.0049325497115801226)
# ('sy_carcino_embryonic_antigen', 0.004907428338490666)
# ('fy_pct', 0.00476396971641764)
# ('sy_albumin_globulin', 0.004514830784932685)
# ('fy_globulin', 0.004493624248042533)
# ('fy_total_cholesterol', 0.004477944217139739)
# ('fy_6000_right', 0.00447578095608089)
# ('fy_creatinine', 0.0044382342673739)
# ('sy_percentage_of_lymphocytes', 0.004264898456963352)
# ('fy_percentage_of_lymphocytes', 0.004165597784789714)
# ('fy_absolute_eosinophil_count', 0.003929691871777998)
# ('sy_lymphocyte_number', 0.003846976462266178)
# ('fy_the_K_value_of_the_ESR_equation', 0.003773738339454099)
# ('fy_apolipoprotein_B100', 0.00362805183360586)
# ('sy_mean_corpuscular_hemoglobin_concentration', 0.0035931105623712707)
# ('sy_diastolic_blood_pressure_low', 0.0035808337468226418)
# ('fy_a_hydroxybutyrate_dehydrogenase', 0.003171358344338109)
# ('sy_large_platelet_ratio', 0.0028509900536941558)
# ('fy_millet_grass_millet_c', 0.0023892193676441006)
# ('fy_r_glutamyl_transpeptidase', 0.0023193047473572754)
# ('fy_percentage_of_monocytes', 0.002316249625248725)
# ('fy_hemameba', 0.0022742870424047744)
# ('sy_6000_left', 0.002274152291880507)
# ('sy_alpha_fetoprotein', 0.002199547576650176)
# ('sy_systolic_blood_pressure_high', 0.0021512204596938252)
# ('sy_3000_left', 0.0021152704775606337)
# ('sy_total_bilirubin', 0.002093268697546121)
# ('fy_red_blood_cell_distribution_width_SD', 0.0020009439397196812)
# ('sy_mean_corpuscular_hemoglobin', 0.0019302857556451516)
# ('fy_total_prostate_specific_antigen', 0.00186840163600294)
# ('fy_sreatine_kinase_isoenzyme', 0.0018326132002918257)
# ('fy_albumin', 0.0017836414011325361)
# ('sy_apolipoprotein_B100', 0.0016676066803038422)
# ('fy_hemoglobin', 0.0016492714250624957)
# ('fy_thyroid_stimulating_hormone', 0.0016393397878936703)
# ('fy_calcium', 0.001631561805889802)
# ('sy_triglyceride', 0.0016188582558706581)
# ('sy_hemameba', 0.0016097422951330228)
# ('fy_absolute_value_of_monocytes', 0.001521863130380726)
# ('sy_neutrophilic_granulocyte_percentage', 0.001517337057845445)
# ('sy_free_T3', 0.0014099673415252062)
# ('fy_alpha_fetoprotein', 0.0013930866052893466)
# ('fy_high_density_lipoprotein_cholesterol', 0.0012975131774158033)
# ('sy_lactic_dehydrogenase', 0.001222917449816638)
# ('sy_2000_right', 0.0011258463851659428)
# ('fy_ESR_blood_sedimentation', 0.0009994936582756269)
# ('sy_globulin', 0.0008946442756164536)
# ('fy_2000_right', 0.0008411963326270898)
# ('sy_free_prostate_specific_antigen', 0.0008243772041053411)
# ('sy_millet_grass_millet_c', 0.000823927778209984)
# ('fy_mean_platelet_volume', 0.0008110381197428568)
# ('fy_total_protein', 0.000803279821625662)
# ('sy_high_density_lipoprotein_cholesterol', 0.0007950593234913839)
# ('fy_ph_value', 0.0007773772236413579)
# ('sy_absolute_neutrophil_count', 0.0007515104008541392)
# ('sy_whole_blood_viscosity_values_3Pas_shear_rate5s', 0.0007333921989912094)
# ('fy_lymphocyte_number', 0.000728063886877357)
# ('fy_mean_corpuscular_volume', 0.0007116988254753026)
# ('fy_whole_blood_viscosity_values_3Pas_shear_rate5s', 0.0006492721653275108)
# ('fy_free_T4', 0.0006418950152860779)
# ('fy_free_prostate_specific_antigen', 0.0006371465497916196)
# ('sy_red_blood_cell_distribution_width_SD', 0.000617103266042829)
# ('fy_high_density_low_density', 0.0005768819390427792)
# ('sy_high_density_low_density', 0.0005481534832368487)
# ('sy_trioxypurine', 0.0005367410015879033)
# ('fy_hematocrit56', 0.0005303699015757577)
# ('sy_total_prostate_specific_antigen', 0.0005273027831803741)
# ('fy_6000_left', 0.0005015353199056963)
# ('sy_albumin', 0.0004930815013500553)
# ('fy_direct_bilirubin', 0.00047672655876056566)
# ('fy_3000_right', 0.0004608751564811531)
# ('sy_carbamide', 0.00037510991655032223)
# ('sy_alkaline_phosphatase', 0.00036602534209971945)
# ('sy_hemoglobin', 0.00034849483979878913)
# ('sy_apolipoprotein_ai', 0.00034321108477557193)
# ('sy_sreatine_kinase_isoenzyme', 0.00033500858792371126)
# ('fy_large_platelet_ratio', 0.0003329063421156353)
# ('sy_glutamic_oxalacetic_transaminase', 0.0003175097477678707)
# ('sy_hematocrit56', 0.00027198516358736065)
# ('sy_3000_right', 0.00024175609974702141)
# ('fy_triglyceride', 0.00019952585721283675)
# ('sy_red_cell_assembling_index', 0.00015343725296232592)
# ('sy_500_right', 0.00015034748510087917)
# ('fy_free_T3', 0.00014854118125695213)
# ('sy_500_left', 0.00014551590240387738)
# ('sy_low_density_lipoprotein_cholesterin', 0.00014207523814282414)
# ('fy_500_left', 7.573167379800137e-05)
# ('sy_mean_platelet_volume', 7.149312068993485e-05)
# ('fy_3000_left', 6.437292596814107e-05)
# ('sy_whole_blood_viscosity_values_1pas_the_shear_rate_200s', 5.684214937651437e-05)
# ('fy_4000_right', 5.205693754306482e-05)
# ('fy_red_blood_cell_distribution_width_CV', 1.2417272255132035e-05)
# ('sy_ESR_blood_sedimentation', 2.2846713015928865e-06)
# ('sy_1000_right', 1.2315203566218998e-06)
# ('fy_absolute_value_of_basophils', 0.0)
# ('fy_erythrocyte', 0.0)
# ('fy_mean_corpuscular_hemoglobin', 0.0)
# ('fy_mean_corpuscular_hemoglobin_concentration', 0.0)
# ('fy_platelet_distribution_width', 0.0)
# ('fy_total_bilirubin', 0.0)
# ('fy_low_density_lipoprotein_cholesterin', 0.0)
# ('fy_carcino_embryonic_antigen', 0.0)
# ('fy_1000_left', 0.0)
# ('fy_2000_left', 0.0)
# ('fy_4000_left', 0.0)
# ('fy_500_right', 0.0)
# ('fy_1000_right', 0.0)
# ('sy_absolute_value_of_monocytes', 0.0)
# ('sy_mean_corpuscular_volume', 0.0)
# ('sy_red_blood_cell_distribution_width_CV', 0.0)
# ('sy_platelet_distribution_width', 0.0)
# ('sy_pct', 0.0)
# ('sy_whole_blood_viscosity_values_4Pas_shear_rate1s', 0.0)
# ('sy_glutamic_pyruvic_transaminase', 0.0)
# ('sy_total_protein', 0.0)
# ('sy_direct_bilirubin', 0.0)
# ('sy_creatine_phosphate_kinase', 0.0)
# ('sy_proportion', 0.0)
# ('sy_ph_value', 0.0)
# ('sy_2000_left', 0.0)
# ('sy_4000_left', 0.0)
# ('sy_6000_right', 0.0)

# %%
# Convert feature importances and RMSE list to DataFrame
feature_importance_df = pd.DataFrame(feature_importances, columns=['Feature', 'Importance'])
rmse_df = pd.DataFrame(rmses, columns=['Number of Features', 'RMSE'])

# Save DataFrames to CSV for use in papers
feature_importance_df.to_csv("feature_importances_ab.csv", index=False)
rmse_df.to_csv("rmse_by_iteration_ab.csv", index=False)

# Print DataFrames to screen (optional, for quick verification)
print("Feature Importances:\n", feature_importance_df)
print("\nRMSE by Iteration:\n", rmse_df)
best_feature_columns = best_data.columns

# Convert column names to a DataFrame
best_features_df = pd.DataFrame(best_feature_columns, columns=['Best Features'])

# Save the DataFrame to CSV
best_features_df.to_csv("best_features_ab.csv", index=False)
# Out:
# Feature Importances:
#                                                 Feature  Importance
# 0                                           fy_glucose    0.298652
# 1                                           sy_glucose    0.159399
# 2    fy_whole_blood_viscosity_values_2Pas_shear_rat...    0.036674
# 3                                         fy_carbamide    0.025523
# 4    fy_whole_blood_viscosity_values_1pas_the_shear...    0.021411
# ..                                                 ...         ...
# 154                                      sy_proportion    0.000000
# 155                                        sy_ph_value    0.000000
# 156                                       sy_2000_left    0.000000
# 157                                       sy_4000_left    0.000000
# 158                                      sy_6000_right    0.000000
#
# [159 rows x 2 columns]
#
# RMSE by Iteration:
#       Number of Features      RMSE
# 0                   159  0.995574
# 1                   158  0.990331
# 2                   157  0.989340
# 3                   156  0.963404
# 4                   155  0.985441
# ..                  ...       ...
# 152                   7  0.514023
# 153                   6  0.412399
# 154                   5  0.450796
# 155                   4  0.512169
# 156                   3  0.535860
#
# [157 rows x 2 columns]
